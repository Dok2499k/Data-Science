# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dm_office_sales.csv')

# %%
df.head()
# Out:
#           division  level of education  training level  work experience  \
# 0         printers        some college               2                6
# 1         printers  associate's degree               2               10
# 2      peripherals         high school               0                9
# 3  office supplies  associate's degree               2                5
# 4  office supplies         high school               1                5
#
#    salary   sales
# 0   91684  372302
# 1  119679  495660
# 2   82045  320453
# 3   92949  377148
# 4   71280  312802

# %%
# https://matplotlib.org/stable/users/explain/colors/colormaps.html - палитры цветов
plt.figure(figsize=(12,4),dpi=200)
sns.scatterplot(data=df,x='salary',y='sales',hue='level of education',
                palette='Dark2',size='level of education')#,style='level of education')
# Out:
# <Axes: xlabel='salary', ylabel='sales'>
